# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (25.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from opencv-python) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe==0.10.9
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mediapipe==0.10.9 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (0.10.9)
# Requirement already satisfied: absl-py in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (24.3.25)
# Requirement already satisfied: matplotlib in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (3.9.2)
# Requirement already satisfied: numpy in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (2.0.2)
# Requirement already satisfied: opencv-contrib-python in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from mediapipe==0.10.9) (0.5.2)
# Requirement already satisfied: CFFI>=1.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from sounddevice>=0.4.4->mediapipe==0.10.9) (1.17.1)
# Requirement already satisfied: pycparser in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.9) (2.22)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe==0.10.9) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe==0.10.9) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.9) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyqt5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyqt5 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (5.15.11)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyqt5) (12.17.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyqt5) (5.15.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyttsx3 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (2.98)
# Requirement already satisfied: pyobjc>=2.4 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-core==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-libdispatch==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-libxpc==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Accessibility==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AdServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AdSupport==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVRouting==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Accounts==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AddressBook==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Automator==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BusinessChat==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CFNetwork==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CalendarStore==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CallKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Carbon==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Cinematic==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ClassKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CloudKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Cocoa==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Collaboration==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ColorSync==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Contacts==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ContactsUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreAudio==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreData==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreLocation==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMedia==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreML==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMotion==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreText==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DataDetection==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DeviceDiscoveryExtension==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiscRecording==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-EventKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FileProvider==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FSEvents==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FinderSync==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameCenter==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameController==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-HealthKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Intents==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IntentsUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InstantMessage==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOSurface==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-KernelManagement==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LaunchServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MailKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MapKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaExtension==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Metal==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalFX==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetricKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MLCompute==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ModelIO==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NetFS==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Network==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OSAKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OSLog==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PassKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PencilKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PHASE==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Photos==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PhotosUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PushKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Quartz==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ReplayKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SafetyKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SafariServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenTime==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Security==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SearchKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ShazamKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Social==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Speech==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SpriteKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-StoreKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SyncServices==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-WebKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameplayKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SceneKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Symbols==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UserNotifications==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Virtualization==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Vision==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==11.0 in /Users/yashrai/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import cv2
import numpy as np
import csv
import datetime
import os
import pyttsx3
import time
import threading
from PyQt5.QtWidgets import (QApplication, QWidget, QLabel, QLineEdit, QPushButton,
                             QVBoxLayout, QHBoxLayout, QMessageBox, QComboBox, QTextEdit, QInputDialog)
from PyQt5.QtCore import Qt, QTimer
from PyQt5.QtGui import QPixmap, QImage
import mediapipe as mp

# Initialize pose detection and drawing
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Initialize voice engine
engine = pyttsx3.init()
engine.setProperty('rate', 180)

# Final working version
import pyttsx3

engine = pyttsx3.init()
voices = engine.getProperty('voices')

# Try to select a female voice (usually index 1, but check your system)
for voice in voices:
    if "female" in voice.name.lower() or "zira" in voice.name.lower():
        engine.setProperty('voice', voice.id)
        break

engine.setProperty('rate', 150)

def speak(text):
    engine.say(text)
    engine.runAndWait()



def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return 360 - angle if angle > 180.0 else angle

def recommend_goal(bmi):
    if bmi < 18.5:
        return 'muscle gain'
    elif bmi < 25:
        return 'maintenance'
    else:
        return 'weight loss'

def recommend_exercises(goal):
    return {
        'squats': 5 if goal in ['weight loss', 'muscle gain'] else 3,
        'pushups': 5 if goal in ['weight loss', 'muscle gain'] else 3,
        'pullups': 3 if goal in ['weight loss', 'muscle gain'] else 2,
        'curls': 5 if goal in ['weight loss', 'muscle gain'] else 3
    }

def write_to_csv(name, age, gender, goal, squats, pushups, pullups, curls):
    file_exists = os.path.exists('FITNESS.csv')
    with open('FITNESS.csv', 'a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(['Name', 'Age', 'Gender', 'Goal', 'Squats', 'Pushups', 'Pullups', 'Curls', 'Timestamp'])
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        writer.writerow([name, age, gender, goal, squats, pushups, pullups, curls, timestamp])

def fetch_user_data(name):
    if not os.path.exists("FITNESS.csv"):
        return "No records found."
    with open("FITNESS.csv", 'r') as f:
        rows = list(csv.reader(f))
        header = rows[0]
        entries = [row for row in rows[1:] if row[0].lower() == name.lower()]
    return "\n".join([" | ".join(entry) for entry in entries[-3:]]) if entries else "No previous records found."

class FitnessApp(QWidget):
    def __init__(self):
        super().__init__()
        self.setWindowTitle('FitSavvy - Smarter fitness, better you')
        self.setGeometry(300, 300, 600, 600)

        self.name_input = QLineEdit()
        self.age_input = QLineEdit()
        self.gender_input = QComboBox()
        self.gender_input.addItems(['Male', 'Female'])
        self.height_input = QLineEdit()
        self.weight_input = QLineEdit()
        self.info_label = QLabel('Enter your details:')
        self.result_label = QLabel('')
        self.history_area = QTextEdit()
        self.history_area.setReadOnly(True)

        self.start_button = QPushButton('Start')
        self.start_button.clicked.connect(self.calculate_bmi)

        layout = QVBoxLayout()
        layout.addWidget(self.info_label)
        layout.addWidget(QLabel('Name:'))
        layout.addWidget(self.name_input)
        layout.addWidget(QLabel('Age:'))
        layout.addWidget(self.age_input)
        layout.addWidget(QLabel('Gender:'))
        layout.addWidget(self.gender_input)
        layout.addWidget(QLabel('Height (cm):'))
        layout.addWidget(self.height_input)
        layout.addWidget(QLabel('Weight (kg):'))
        layout.addWidget(self.weight_input)
        layout.addWidget(self.start_button)
        layout.addWidget(self.result_label)
        layout.addWidget(QLabel("Recent Workout History:"))
        layout.addWidget(self.history_area)
        self.setLayout(layout)

    def calculate_bmi(self):
        try:
            name = self.name_input.text()
            age = self.age_input.text()
            gender = self.gender_input.currentText()
            height = float(self.height_input.text()) / 100
            weight = float(self.weight_input.text())
            bmi = weight / (height ** 2)
            goal = recommend_goal(bmi)
            self.result_label.setText(f"Your BMI is {bmi:.2f}. Suggested goal: {goal}.")
            speak(f"Your BMI is {int(bmi)}. Suggested goal is {goal}. Do you want to start with this goal?")
            time.sleep(0.5)  # Optional
            self.ask_goal_confirmation(name, age, gender, goal)
            self.history_area.setText(fetch_user_data(name))
        except Exception as e:
            QMessageBox.warning(self, "Input Error", f"Invalid input: {str(e)}")


    def ask_goal_confirmation(self, name, age, gender, goal):
        reply = QMessageBox.question(self, 'Confirm Goal',
                                     f'Do you want to proceed with the suggested goal: {goal}?',
                                     QMessageBox.Yes | QMessageBox.No, QMessageBox.Yes)
        if reply == QMessageBox.Yes:
            self.close()
            start_workout(name, age, gender, goal)
        else:
            custom_goal, ok = QInputDialog.getItem(self, "Select Goal", "Choose your goal:",
                                                   ["weight loss", "muscle gain", "maintenance"], 0, False)
            if ok and custom_goal:
                self.close()
                start_workout(name, age, gender, custom_goal)

def start_workout(name, age, gender, goal):
    exercise_targets = recommend_exercises(goal)
    cap = cv2.VideoCapture(0)
    address="https://192.168.165.82:8080/video"
    cap.open(address)
    counters = {'squats': 0, 'pushups': 0, 'pullups': 0, 'curls': 0}
    stages = {'squats': None, 'pushups': None, 'pullups': None, 'curls': None}
    current = 'squats'
    speak("Starting workout with squats")

    with mp_pose.Pose(min_detection_confidence=0.8, min_tracking_confidence=0.9) as pose:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                continue
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            if results.pose_landmarks:
                lm = results.pose_landmarks.landmark
                try:
                    if current == 'squats':
                        angle = calculate_angle(
                            [lm[mp_pose.PoseLandmark.LEFT_HIP.value].x, lm[mp_pose.PoseLandmark.LEFT_HIP.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_KNEE.value].x, lm[mp_pose.PoseLandmark.LEFT_KNEE.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, lm[mp_pose.PoseLandmark.LEFT_ANKLE.value].y])
                        if angle > 160:
                            stages[current] = 'up'
                        elif angle < 90 and stages[current] == 'up':
                            stages[current] = 'down'
                            counters[current] += 1
                            speak(f"Squat {counters[current]}")
                            if counters[current] >= exercise_targets[current]:
                                current = 'pushups'
                                speak("Next: Pushups")

                    elif current == 'pushups':
                        angle = calculate_angle(
                            [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y])
                        if angle > 160:
                            stages[current] = 'up'
                        elif angle < 90 and stages[current] == 'up':
                            stages[current] = 'down'
                            counters[current] += 1
                            speak(f"Pushup {counters[current]}")
                            if counters[current] >= exercise_targets[current]:
                                current = 'pullups'
                                speak("Next: Pullups")

                    elif current == 'pullups':
                        angle = calculate_angle(
                            [lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y],
                            [lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y],
                            [lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].y])
                        if angle > 160:
                            stages[current] = 'up'
                        elif angle < 90 and stages[current] == 'up':
                            stages[current] = 'down'
                            counters[current] += 1
                            speak(f"Pullup {counters[current]}")
                            if counters[current] >= exercise_targets[current]:
                                current = 'curls'
                                speak("Next: Curls")

                    elif current == 'curls':
                        angle = calculate_angle(
                            [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y],
                            [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y])
                        if angle > 160:
                            stages[current] = 'down'
                        elif angle < 40 and stages[current] == 'down':
                            stages[current] = 'up'
                            counters[current] += 1
                            speak(f"Curl {counters[current]}")
                            if counters[current] >= exercise_targets[current]:
                                speak("Workout complete")
                                write_to_csv(name, age, gender, goal,
                                             counters['squats'], counters['pushups'],
                                             counters['pullups'], counters['curls'])
                                break
                except:
                    pass

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
            for i, (ex, count) in enumerate(counters.items()):
                cv2.putText(image, f"{ex.capitalize()}: {count}/{exercise_targets[ex]}", (10, 30+i*30),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

            cv2.imshow('Workout Tracker', image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    win = FitnessApp()
    win.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/yashrai/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
